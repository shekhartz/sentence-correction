# %% [markdown]
# # Comparative Summary of all Models

# %%
import pandas as pd

# %% [markdown]
# ## Baseline Model

# %%
df = pd.DataFrame(columns=['Model', 'Embedding', 'Level', 'Epoch', 'Train Loss', 'Val Loss', 'Train BLEU', 'Test BLEU'])
print('--------------------------------SUMMARY OF BASELINE MODEL---------------------------------')
print('='*90)
df.loc[len(df.index)] = ['1Layer-GRU', 'Scratch', 'Word', 20, 1.38, 1.69, 0.44, 0.41]
df.loc[len(df.index)] = ['1Layer-GRU', 'Glove', 'Word', 20, 1.59, 1.67, 0.45, 0.43]  
df.loc[len(df.index)] = ['1Layer-GRU', 'Fasttext', 'Word', 20, 1.64, 1.69, 0.46, 0.44]  

df.loc[len(df.index)] = ['1Layer-LSTM', 'Scratch', 'Word', 20, 1.38, 1.67, 0.44, 0.44]
df.loc[len(df.index)] = ['1Layer-LSTM', 'Glove', 'Word', 20, 1.63, 1.68, 0.44, 0.43]  
df.loc[len(df.index)] = ['1Layer-LSTM', 'Fasttext', 'Word', 20, 1.71, 1.72, 0.43, 0.46]  

df.loc[len(df.index)] = ['1Layer-BidirectionalLSTM', 'Scratch', 'Word', 20, 1.18, 1.54, 0.43, 0.42]
df.loc[len(df.index)] = ['1Layer-BidirectionalLSTM', 'Glove', 'Word', 20, 1.26, 1.44, 0.42, 0.42]  
df.loc[len(df.index)] = ['1Layer-BidirectionalLSTM', 'Fasttext', 'Word', 20, 1.38, 1.46, 0.42, 0.41]  

df
# Out:
# --------------------------------SUMMARY OF BASELINE MODEL---------------------------------
# ...
#                       Model Embedding Level  ... Val Loss  Train BLEU  Test BLEU
# 0                1Layer-GRU   Scratch  Word  ...     1.69        0.44       0.41
# 1                1Layer-GRU     Glove  Word  ...     1.67        0.45       0.43
# 2                1Layer-GRU  Fasttext  Word  ...     1.69        0.46       0.44
# 3               1Layer-LSTM   Scratch  Word  ...     1.67        0.44       0.44
# 4               1Layer-LSTM     Glove  Word  ...     1.68        0.44       0.43
# 5               1Layer-LSTM  Fasttext  Word  ...     1.72        0.43       0.46
# 6  1Layer-BidirectionalLSTM   Scratch  Word  ...     1.54        0.43       0.42
# 7  1Layer-BidirectionalLSTM     Glove  Word  ...     1.44        0.42       0.42
# 8  1Layer-BidirectionalLSTM  Fasttext  Word  ...     1.46        0.42       0.41
#
# [9 rows x 8 columns]

# %% [markdown]
# ## Attention Model

# %%
df = pd.DataFrame(columns=['Model', 'Embedding', 'Level', 'Epoch', 'Train Loss', 'Val Loss', 'Train BLEU', 'Test BLEU'])
print('--------------------------------SUMMARY OF ATTENTION MODEL--------------------------------')
print('='*90)

df.loc[len(df.index)] = ['1Layer-LSTM', 'Scratch', 'Char', 20, 0.46, 0.46, 0.02, 0.06]
df.loc[len(df.index)] = ['1Layer-LSTM', 'Scratch', 'Char', 40, 0.38, 0.38, 0.05, 0.05]  

df.loc[len(df.index)] = ['1Layer-LSTM', 'Scratch', 'Word', 90, 0.29, 0.29, 0.76, 0.46]  

df.loc[len(df.index)] = ['1Layer-LSTM', 'Fasttext', 'Word', 60, 0.35, 0.35, 0.62, 0.52]
df.loc[len(df.index)] = ['1Layer-LSTM', 'Fasttext', 'Word', 90, 0.24, 0.23, 0.69, 0.49]  

df.loc[len(df.index)] = ['2Layer-LSTM', 'Scratch', 'Word', 40, 0.34, 0.33, 0.71, 0.50]
df.loc[len(df.index)] = ['2Layer-LSTM', 'Scratch', 'Word', 70, 0.19, 0.19, 0.81, 0.47]  

df.loc[len(df.index)] = ['1Layer-BidirectionalLSTM', 'Fasttext', 'Word', 40, 0.34, 0.31, 0.65, 0.53]
df.loc[len(df.index)] = ['1Layer-BidirectionalLSTM', 'Fasttext', 'Word', 80, 0.12, 0.10, 0.84, 0.50]  

df
# Out:
# --------------------------------SUMMARY OF ATTENTION MODEL--------------------------------
# ...
#                       Model Embedding Level  ... Val Loss  Train BLEU  Test BLEU
# 0               1Layer-LSTM   Scratch  Char  ...     0.46        0.02       0.06
# 1               1Layer-LSTM   Scratch  Char  ...     0.38        0.05       0.05
# 2               1Layer-LSTM   Scratch  Word  ...     0.29        0.76       0.46
# 3               1Layer-LSTM  Fasttext  Word  ...     0.35        0.62       0.52
# 4               1Layer-LSTM  Fasttext  Word  ...     0.23        0.69       0.49
# 5               2Layer-LSTM   Scratch  Word  ...     0.33        0.71       0.50
# 6               2Layer-LSTM   Scratch  Word  ...     0.19        0.81       0.47
# 7  1Layer-BidirectionalLSTM  Fasttext  Word  ...     0.31        0.65       0.53
# 8  1Layer-BidirectionalLSTM  Fasttext  Word  ...     0.10        0.84       0.50
#
# [9 rows x 8 columns]
